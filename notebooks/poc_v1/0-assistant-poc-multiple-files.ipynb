# %%
import os
import openai
import pandas as pd
import json
from io import StringIO
from langchain_openai import ChatOpenAI
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate
# If you want to chunk PDF text, you can also import TextSplitter utilities:
# from langchain.text_splitter import RecursiveCharacterTextSplitter
import PyPDF2
from dotenv import load_dotenv
import os

# %%
load_dotenv()
OPENAI_API_KEY= os.getenv('OPENAI_API_KEY')
# In code, you might do:
# openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
def extract_text_from_pdf(pdf_path: str) -> str:
    """
    Extract all text from a PDF file using PyPDF2.
    """
    text_content = []
    with open(pdf_path, 'rb') as f:
        reader = PyPDF2.PdfReader(f)
        for page in reader.pages:
            text_content.append(page.extract_text())
    return "\n".join(text_content)


def summarize_excel_folder_to_json(folder_path):
    """
    Reads all Excel (.xlsx) files in the specified folder and creates a JSON summary
    that includes each file and its sheets. For each sheet, the summary for every column includes:
      1. The variable (column) name.
      2. The inferred variable type (numeric, datetime, categorical).
      3. For numeric columns: standard summary statistics.
      4. For categorical columns: unique values and their counts.
      5. For datetime columns: the time span (min and max dates).

    The final JSON structure is organized with file names as top-level keys, and each file contains
    a dictionary of its sheet names and their summaries.

    Parameters:
        folder_path (str): The path to the folder containing Excel files.

    Returns:
        str: A JSON string summarizing all the Excel files and their sheets.
    """
    folder_summary = {}

    # Loop through each file in the provided folder
    for file_name in os.listdir(folder_path):
        # Only process files with a .xlsx extension
        if file_name.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file_name)
            try:
                xls = pd.ExcelFile(file_path)
            except Exception as e:
                # If there is an error reading the file, record the error and continue
                folder_summary[file_name] = {"error": f"Failed to read file: {e}"}
                continue

            file_summary = {}
            # Process each sheet in the workbook
            for sheet in xls.sheet_names:
                try:
                    df = pd.read_excel(xls, sheet_name=sheet)
                except Exception as e:
                    file_summary[sheet] = {"error": f"Failed to read sheet: {e}"}
                    continue

                sheet_summary = []
                # Process each column in the sheet
                for col in df.columns:
                    column_summary = {"variable_name": str(col)}
                    series = df[col]

                    # Determine the type of the column: numeric, datetime, or categorical
                    if pd.api.types.is_numeric_dtype(series):
                        column_summary["variable_type"] = "numeric"
                        stats = series.describe()
                        column_summary["summary_statistics"] = {
                            "count": stats.get("count"),
                            "mean": stats.get("mean"),
                            "std": stats.get("std"),
                            "min": stats.get("min"),
                            "25%": stats.get("25%"),
                            "50%": stats.get("50%"),
                            "75%": stats.get("75%"),
                            "max": stats.get("max")
                        }
                    elif pd.api.types.is_datetime64_any_dtype(series):
                        column_summary["variable_type"] = "datetime"
                        times = series.dropna()
                        if not times.empty:
                            column_summary["time_span"] = {
                                "start": str(times.min()),
                                "end": str(times.max())
                            }
                        else:
                            column_summary["time_span"] = {"start": None, "end": None}
                    else:
                        column_summary["variable_type"] = "categorical"
                        uniques = series.value_counts(dropna=False)
                        unique_values = []
                        for value, count in uniques.items():
                            # Represent NaN values as the string "NaN"
                            value_str = "NaN" if pd.isna(value) else str(value)
                            unique_values.append({"value": value_str, "count": int(count)})
                        column_summary["unique_values"] = unique_values

                    sheet_summary.append(column_summary)
                file_summary[sheet] = sheet_summary

            folder_summary[file_name] = file_summary

    # Convert the complete folder summary into a formatted JSON string
    json_str = json.dumps(folder_summary, indent=2)
    return json_str

# %%
xlsx_path = "../data/poc_data_and_similar_paper"
dataset_summary = summarize_excel_folder_to_json(xlsx_path)

# %%
from pprint import pprint
pprint(dataset_summary)
# Out:
# ('{\n'
#  '  "fourth_corner_functional_diversity.xlsx": {\n'
#  '    "wild_bee_traits": [\n'
#  '      {\n'
#  '        "variable_name": "Ecological traits of wild bees",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_qua",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_maj",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_mal",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_min",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_mor",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_nit",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_nid",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_par",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_pau",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_pun",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_ruf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lin",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_sab",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_sem",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_sex",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_ses",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_tar",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_vil",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_zon",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_cen",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_cir",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_luc",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lec",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_lea",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_sin",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_hya",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_lep",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_nig",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_nir",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_pau",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_pic",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_pun",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_puc",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_sig",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_sty",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_leu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_alb",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_bre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_cal",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_ful",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_int",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lav",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lae",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_let",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lat",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_eri",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_lig",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Species code",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_fer",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "osm_bic",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "osm_bio",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "osm_cae",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "osm_lea",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "pan_cal",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "rop_qui",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_alb",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_cra",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_eph",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_gib",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_sig",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_lon",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_min",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_mon",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_pel",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_ret",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_ruf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_sca",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ste_bre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ste_pun",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "osm_aur",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_she",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_mar",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_fab",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_rot",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_ver",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_wil",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "mel_alb",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "mel_hae",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "mel_lep",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_bif",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_cas",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_con",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_fla",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_pan",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_flo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_flv",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_fuc",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_ful",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_goo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_leu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_mar",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_moe",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_opa",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_gre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_dil",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_dif",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pro",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_min",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_miu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_nig",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_nit",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_niv",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_ova",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pil",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pot",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pra",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_prx",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_lai",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_sub",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_tib",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_vag",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_ven",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_wil",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_str",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_man",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_obl",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_bim",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_lep",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_hum",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_cor",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_den",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_alf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_bar",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_bic",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_bim",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_car",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_chy",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_chr",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_cin",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_cla",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_dor",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_hel",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_fal",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_fla",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_flr",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_flo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_ful",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_fug",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_gra",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_hae",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_hat",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_fur",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_plu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_qua",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_sub",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "das_mor",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "epe_cru",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "epe_var",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "euc_lon",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_con",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_leu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_qua",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_rub",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_sex",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_tum",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_boh",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "her_cre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "her_tru",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hop_adu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hop_ant",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hop_leu",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_ang",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_bre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_com",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_con",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "das_hir",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "col_sim",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "col_fod",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "col_dav",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_hor",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_hyp",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_lap",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ter_bom",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_mus",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_pas",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_pra",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_rud",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_rup",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_syl",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_ves",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "cer_cya",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "chel_cam",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "chel_flo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "chel_rap",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "coe_elo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "coe_ine",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "coe_ruf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "col_cun",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "thy_orb",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 1",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "Halictidae",\n'
#  '            "count": 51\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Andrenidae",\n'
#  '            "count": 41\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Apidae",\n'
#  '            "count": 39\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Megachilidae",\n'
#  '            "count": 30\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Colletidae",\n'
#  '            "count": 23\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Melittidae",\n'
#  '            "count": 4\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Family",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 2",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "solit",\n'
#  '            "count": 123\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 41\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "euso",\n'
#  '            "count": 24\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Social behavior",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 3",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "soil",\n'
#  '            "count": 97\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 41\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "cav",\n'
#  '            "count": 38\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hiv",\n'
#  '            "count": 12\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Nesting place",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 4",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "poly",\n'
#  '            "count": 115\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 41\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "oli",\n'
#  '            "count": 32\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Floral specificity",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 5",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "May/June",\n'
#  '            "count": 88\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "March/April",\n'
#  '            "count": 88\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "July/August",\n'
#  '            "count": 12\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Flight beginning period ",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 6",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "July/August",\n'
#  '            "count": 93\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "September/October",\n'
#  '            "count": 60\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "May/June",\n'
#  '            "count": 35\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "End of flight period ",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 7",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "3",\n'
#  '            "count": 64\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "5",\n'
#  '            "count": 33\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "4",\n'
#  '            "count": 28\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "7",\n'
#  '            "count": 27\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "2",\n'
#  '            "count": 23\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "6",\n'
#  '            "count": 11\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Lifespan [month]",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "8",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "1",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 8",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "mon",\n'
#  '            "count": 156\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "biv",\n'
#  '            "count": 32\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Voltinism ",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 9",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "scopa on leg",\n'
#  '            "count": 93\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 41\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "scopa on abdomen",\n'
#  '            "count": 25\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "crop",\n'
#  '            "count": 20\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "corbicula on leg",\n'
#  '            "count": 9\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Pollen carrying-structure",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 10",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "medium",\n'
#  '            "count": 115\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "small",\n'
#  '            "count": 69\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "large",\n'
#  '            "count": 4\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Mean body size",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Unnamed: 11",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "common",\n'
#  '            "count": 155\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "rare",\n'
#  '            "count": 32\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Rarity",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      }\n'
#  '    ],\n'
#  '    "wild_bees": [\n'
#  '      {\n'
#  '        "variable_name": "Shortest distance between sites [m]",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 3431.111745186738,\n'
#  '          "std": 4687.589327968573,\n'
#  '          "min": 527.72304922244,\n'
#  '          "25%": 789.7203906773473,\n'
#  '          "50%": 1532.958599849545,\n'
#  '          "75%": 4263.752769972711,\n'
#  '          "max": 20068.5165459586\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Site number",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "site 1",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 2",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 21",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 20",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 19",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 18",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 17",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 16",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 15",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 14",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 13",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 12",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 11",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 10",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 9",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 8",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 7",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 6",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 5",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 4",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 3",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 22",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Landscape type",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "urban",\n'
#  '            "count": 11\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "rural",\n'
#  '            "count": 11\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Year of research",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 2018.590909090909,\n'
#  '          "std": 0.5032362797401964,\n'
#  '          "min": 2018.0,\n'
#  '          "25%": 2018.0,\n'
#  '          "50%": 2019.0,\n'
#  '          "75%": 2019.0,\n'
#  '          "max": 2019.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_alf",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.4090909090909091,\n'
#  '          "std": 1.3330627431056188,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 6.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_bar",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.5454545454545454,\n'
#  '          "std": 1.0107645728086347,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 1.0,\n'
#  '          "max": 4.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_bic",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.09090909090909091,\n'
#  '          "std": 0.29424494316824984,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_bim",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.4090909090909091,\n'
#  '          "std": 0.7341396590302414,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 1.0,\n'
#  '          "max": 3.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_car",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.13636363636363635,\n'
#  '          "std": 0.4675625290960757,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 2.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_chy",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.2132007163556105,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_chr",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 3.227272727272727,\n'
#  '          "std": 11.463946873659085,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 1.0,\n'
#  '          "max": 54.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_cin",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.2727272727272727,\n'
#  '          "std": 0.5504818825631804,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 2.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_cla",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.21320071635561047,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_den",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.2727272727272727,\n'
#  '          "std": 0.7672969364884685,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 3.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_dor",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 3.0454545454545454,\n'
#  '          "std": 4.029383418828585,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 2.0,\n'
#  '          "75%": 3.75,\n'
#  '          "max": 15.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_fal",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.09090909090909091,\n'
#  '          "std": 0.29424494316824984,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_fla",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 7.2727272727272725,\n'
#  '          "std": 13.718884510330719,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 1.0,\n'
#  '          "50%": 3.0,\n'
#  '          "75%": 4.0,\n'
#  '          "max": 53.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_flr",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 2.909090909090909,\n'
#  '          "std": 7.315405082095694,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 24.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_flo",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.2132007163556105,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_ful",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 2.1818181818181817,\n'
#  '          "std": 5.067509613178221,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.5,\n'
#  '          "75%": 1.0,\n'
#  '          "max": 23.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_fug",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.13636363636363635,\n'
#  '          "std": 0.35125008665710444,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_gra",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 3.227272727272727,\n'
#  '          "std": 5.927593410176144,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 4.0,\n'
#  '          "max": 23.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_hae",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 10.045454545454545,\n'
#  '          "std": 11.737109535986287,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 2.0,\n'
#  '          "50%": 7.0,\n'
#  '          "75%": 12.25,\n'
#  '          "max": 49.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_hat",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.21320071635561044,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_hel",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.4090909090909091,\n'
#  '          "std": 0.9591211706105854,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 4.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_hum",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 1.0909090909090908,\n'
#  '          "std": 3.544399887536755,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 15.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_lai",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.7727272727272727,\n'
#  '          "std": 2.2024189770907237,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 10.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_lep",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.09090909090909091,\n'
#  '          "std": 0.4264014327112209,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 2.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_min",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 2.3636363636363638,\n'
#  '          "std": 3.8980514612823156,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 1.0,\n'
#  '          "75%": 2.75,\n'
#  '          "max": 16.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_miu",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 5.090909090909091,\n'
#  '          "std": 6.809720579604892,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 1.0,\n'
#  '          "50%": 2.5,\n'
#  '          "75%": 4.75,\n'
#  '          "max": 24.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_nig",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 3.4545454545454546,\n'
#  '          "std": 6.946923078582364,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 1.5,\n'
#  '          "75%": 2.75,\n'
#  '          "max": 31.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_nit",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 1.5,\n'
#  '          "std": 3.12821263435117,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 1.75,\n'
#  '          "max": 13.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_niv",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.36363636363636365,\n'
#  '          "std": 1.2926699776028188,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 6.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_ova",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.2132007163556105,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_pil",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.13636363636363635,\n'
#  '          "std": 0.35125008665710444,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_pot",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.09090909090909091,\n'
#  '          "std": 0.29424494316824984,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_pra",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.45454545454545453,\n'
#  '          "std": 0.9116846116771035,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.75,\n'
#  '          "max": 3.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_pro",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.2132007163556105,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_prx",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 1.4545454545454546,\n'
#  '          "std": 2.6318067798390756,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 1.75,\n'
#  '          "max": 9.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_sub",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 1.8181818181818181,\n'
#  '          "std": 2.383202400060406,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 1.0,\n'
#  '          "75%": 3.0,\n'
#  '          "max": 10.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_tib",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.9090909090909091,\n'
#  '          "std": 1.1087999050492516,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 1.0,\n'
#  '          "75%": 1.0,\n'
#  '          "max": 4.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_vag",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.6818181818181818,\n'
#  '          "std": 2.5706468268171556,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 12.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_ven",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.6363636363636364,\n'
#  '          "std": 1.5289415743128763,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 1.0,\n'
#  '          "max": 7.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "and_wil",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.21320071635561044,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
#  '          "max": 1.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "ant_str",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 22.0,\n'
#  '          "mean": 0.045454545454545456,\n'
#  '          "std": 0.2132007163556105,\n'
#  '          "min": 0.0,\n'
#  '          "25%": 0.0,\n'
#  '          "50%": 0.0,\n'
#  '          "75%": 0.0,\n'
# ...
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_qua",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_fer",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pil",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_cra",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hal_con",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_gib",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_car",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_fug",\n'
#  '            "count": 3\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_lep",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_fal",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_she",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_opa",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_pun",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_nig",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pot",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_cor",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_fuc",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lav",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_cir",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_puc",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_sca",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hop_ant",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_bic",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_pau",\n'
#  '            "count": 2\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_wil",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_con",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_mus",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_bre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_alb",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "rop_qui",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "coe_ine",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_flo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_rup",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_pro",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "coe_elo",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_chy",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_tar",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_ruf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_min",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "bom_ves",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_obl",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lat",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_fla",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "coe_ruf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ant_str",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "meg_lea",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "mel_hae",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_ruf",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_ret",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_cla",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "sph_min",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "thy_orb",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_hat",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "epe_cru",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "ste_bre",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "euc_lon",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hyl_nir",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "and_ova",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "las_lin",\n'
#  '            "count": 1\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "nom_leu",\n'
#  '            "count": 1\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Sex",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "female",\n'
#  '            "count": 3686\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "male",\n'
#  '            "count": 2077\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Site number",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "site 21",\n'
#  '            "count": 813\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 9",\n'
#  '            "count": 535\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 2",\n'
#  '            "count": 391\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 22",\n'
#  '            "count": 385\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 19",\n'
#  '            "count": 371\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 11",\n'
#  '            "count": 317\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 10",\n'
#  '            "count": 301\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 18",\n'
#  '            "count": 276\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 8",\n'
#  '            "count": 267\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 15",\n'
#  '            "count": 248\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 3",\n'
#  '            "count": 245\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 4",\n'
#  '            "count": 235\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 17",\n'
#  '            "count": 196\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 16",\n'
#  '            "count": 190\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 12",\n'
#  '            "count": 160\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 5",\n'
#  '            "count": 144\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 1",\n'
#  '            "count": 143\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 13",\n'
#  '            "count": 124\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 7",\n'
#  '            "count": 124\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 14",\n'
#  '            "count": 123\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 6",\n'
#  '            "count": 95\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "site 20",\n'
#  '            "count": 80\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Year",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 5763.0,\n'
#  '          "mean": 2018.621898316849,\n'
#  '          "std": 0.48495526518976806,\n'
#  '          "min": 2018.0,\n'
#  '          "25%": 2018.0,\n'
#  '          "50%": 2019.0,\n'
#  '          "75%": 2019.0,\n'
#  '          "max": 2019.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Month",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "July",\n'
#  '            "count": 1743\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "June",\n'
#  '            "count": 1199\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "May",\n'
#  '            "count": 1189\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "April",\n'
#  '            "count": 980\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "August",\n'
#  '            "count": 652\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Day",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 5763.0,\n'
#  '          "mean": 10.149921915668923,\n'
#  '          "std": 7.957502397458916,\n'
#  '          "min": 1.0,\n'
#  '          "25%": 3.0,\n'
#  '          "50%": 7.0,\n'
#  '          "75%": 17.0,\n'
#  '          "max": 28.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Family",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "Halictidae",\n'
#  '            "count": 1922\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Andrenidae",\n'
#  '            "count": 1348\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Colletidae",\n'
#  '            "count": 911\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Apidae",\n'
#  '            "count": 911\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Megachilidae",\n'
#  '            "count": 485\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "Melittidae",\n'
#  '            "count": 186\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Social behavior",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "solit",\n'
#  '            "count": 3546\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "euso",\n'
#  '            "count": 1948\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 269\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Nesting place",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "soil",\n'
#  '            "count": 4087\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "cav",\n'
#  '            "count": 850\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "hiv",\n'
#  '            "count": 557\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 269\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Floral specificity",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "poly",\n'
#  '            "count": 4852\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "oli",\n'
#  '            "count": 642\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 269\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Flight beginning period ",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "March/April",\n'
#  '            "count": 3555\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "May/June",\n'
#  '            "count": 1869\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "July/August",\n'
#  '            "count": 339\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "End of flight period ",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "September/October",\n'
#  '            "count": 2933\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "July/August",\n'
#  '            "count": 1846\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "May/June",\n'
#  '            "count": 984\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Lifespan [month]",\n'
#  '        "variable_type": "numeric",\n'
#  '        "summary_statistics": {\n'
#  '          "count": 5763.0,\n'
#  '          "mean": 4.794551448898143,\n'
#  '          "std": 1.8547924227614776,\n'
#  '          "min": 1.0,\n'
#  '          "25%": 3.0,\n'
#  '          "50%": 5.0,\n'
#  '          "75%": 7.0,\n'
#  '          "max": 8.0\n'
#  '        }\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Voltinism ",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "mon",\n'
#  '            "count": 5048\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "biv",\n'
#  '            "count": 715\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Pollen carrying-structure",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "scopa on leg",\n'
#  '            "count": 4068\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "corbicula on leg",\n'
#  '            "count": 546\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "scopa on abdomen",\n'
#  '            "count": 473\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "crop",\n'
#  '            "count": 407\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "clep",\n'
#  '            "count": 269\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Mean body size",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "medium",\n'
#  '            "count": 3069\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "small",\n'
#  '            "count": 2363\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "large",\n'
#  '            "count": 331\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      {\n'
#  '        "variable_name": "Rarity",\n'
#  '        "variable_type": "categorical",\n'
#  '        "unique_values": [\n'
#  '          {\n'
#  '            "value": "common",\n'
#  '            "count": 5370\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "rare",\n'
#  '            "count": 390\n'
#  '          },\n'
#  '          {\n'
#  '            "value": "NaN",\n'
#  '            "count": 3\n'
#  '          }\n'
#  '        ]\n'
#  '      }\n'
#  '    ]\n'
#  '  }\n'
#  '}')

# %%
import tiktoken

encoding = tiktoken.get_encoding("cl100k_base")

tokens = encoding.encode(dataset_summary)
print(len(tokens))

# To decode tokens back to text:
decoded_text = encoding.decode(tokens)
# Out:
# 205128
